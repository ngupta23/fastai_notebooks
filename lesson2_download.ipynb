# %% [markdown]
# <a href="https://colab.research.google.com/github/ngupta23/fastai_notebooks/blob/master/lesson2_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
import fastai
from fastai.vision import *
print(fastai.__version__)

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. Before running the following commands, you may want to disable ad blocking extensions (uBlock, AdBlockPlus etc.) in Chrome. Otherwise the window.open() command doesn't work. Then you can run the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %%
# If running this on Google colab, set this to True so it can pick the dataset from Google Drive
# Else, assuming that it is running locally and will pick the dataset from local computer.
colab = False

# %%
# https://course.fast.ai/start_colab.html
if colab: 
    from google.colab import drive
    drive.mount('/content/gdrive', force_remount=True)
    root_dir = "/content/gdrive/My Drive/"
    base_dir = root_dir + 'fastai-v3/'
else:
    base_dir = "./"

# %%
classes = ['qutub', 'eiffel', 'burj', 'oneworldtrade', 'patronas', 'searstower', 'tajmahal', 'unknown']

# %%
# folder = 'qutub'
# file = 'urls_qutub.csv'

# folder = 'eiffel'
# file = 'urls_eiffel.csv'

# folder = 'burj'
# file = 'urls_burj.csv'

# folder = 'oneworldtrade'
# file = 'urls_oneworldtrade.csv'

# folder = 'patronas'
# file = 'urls_patronas.csv'

# folder = 'searstower'
# file = 'urls_searstower.csv'

# folder = 'tajmahal'
# file = 'urls_tajmahal.csv'

# folder = 'unknown'
# file = 'urls_unknown.csv'

# %% [markdown]
# You will need to run this cell once per each category.

# %%
path = Path(base_dir + 'data/landmarks')
# dest = path/folder
# dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [WindowsPath('data/landmarks/burj'),
#  WindowsPath('data/landmarks/cleaned.csv'),
#  WindowsPath('data/landmarks/eiffel'),
#  WindowsPath('data/landmarks/models'),
#  WindowsPath('data/landmarks/oneworldtrade'),
#  WindowsPath('data/landmarks/patronas'),
#  WindowsPath('data/landmarks/qutub'),
#  WindowsPath('data/landmarks/searstower'),
#  WindowsPath('data/landmarks/tajmahal'),
#  WindowsPath('data/landmarks/unknown'),
#  WindowsPath('data/landmarks/urls_burj.csv'),
#  WindowsPath('data/landmarks/urls_eiffel.csv'),
#  WindowsPath('data/landmarks/urls_oneworldtrade.csv'),
#  WindowsPath('data/landmarks/urls_patronas.csv'),
#  WindowsPath('data/landmarks/urls_qutub.csv'),
#  WindowsPath('data/landmarks/urls_searstower.csv'),
#  WindowsPath('data/landmarks/urls_tajmahal.csv'),
#  WindowsPath('data/landmarks/urls_unknown.csv')]

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](https://github.com/fastai/course-v3/blob/master/nbs/dl1/images/download_images/upload.png?raw=1)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
# download_images(path/file, dest, max_pics=200)

# %%
# # If you have problems download, try with `max_workers=0` to see exceptions:
# download_images(path/file, dest, max_pics=20, max_workers=0)

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
# for c in classes:
#     print(c)
#     verify_images(path/c, delete=True, max_size=500)

# %% [markdown]
# ## View data

# %%
# np.random.seed(42)
# data = ImageDataBunch.from_folder(path,
#                                   train=".",
#                                   valid_pct=0.2,
#                                   ds_tfms=get_transforms(),
#                                   size=224,
#                                   bs=16,
#                                   num_workers=4
#                                  ).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
np.random.seed(42)
data = ImageDataBunch.from_csv(path,
                               folder=".",
                               valid_pct=0.2,
                               csv_labels='cleaned.csv',
                               ds_tfms=get_transforms(),
                               bs=16,
                               size=224,
                               num_workers=4
                              ).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.show_batch(rows=4, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['burj',
#   'eiffel',
#   'oneworldtrade',
#   'patronas',
#   'qutub',
#   'searstower',
#   'tajmahal',
#   'unknown'],
#  8,
#  1000,
#  250)

# %% [markdown]
# ## Train model

# %%
learn = cnn_learner(data, models.resnet50, metrics=[error_rate, accuracy])

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.957686</td>
#       <td>0.297208</td>
#       <td>0.104000</td>
#       <td>0.896000</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.595267</td>
#       <td>0.241571</td>
#       <td>0.096000</td>
#       <td>0.904000</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.402699</td>
#       <td>0.233465</td>
#       <td>0.092000</td>
#       <td>0.908000</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.321026</td>
#       <td>0.212261</td>
#       <td>0.080000</td>
#       <td>0.920000</td>
#       <td>01:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
print(learn.path) # --> This is where the model will be saved (under a folder called "models"))
learn.save('stage-1a')
# Out:
# data\landmarks

# %%
# Looks like trainng error is still more than validation error, so model is underfitting.
# We can train some more
learn.fit_one_cycle(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.304750</td>
#       <td>0.247083</td>
#       <td>0.084000</td>
#       <td>0.916000</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.305945</td>
#       <td>0.200755</td>
#       <td>0.064000</td>
#       <td>0.936000</td>
#       <td>01:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-1b')

# %%
learn.unfreeze()

# %%
learn.lr_find()
## If the plot is not showing try to give a start and end learning rate
# learn.lr_find(start_lr=1e-5, end_lr=1e-1)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ### <font color = red>RULE OF THUMB:<font>
#
# * **End value is about 1 order of magnitude lower (divide by 10 or even 5 is OK) than the one in stage1 (which defaulted to 0.003 which is close to 1e-3, so we use ~ 1e-4)**
# * **Start value should come from the learning rate finder and should be well below the value at which the loss starts to become worse. <font color = red>Look for the strongest downward slope that is sticking around for a while</font>. Pick that as the lower end of the learning rate (used for the earlier layers). <font color = red> If there is no downward trend like in the plot above, then pick about 1 order of magnitude before it starts to get worse</font>**

# %%
# These values of learning rate range [slice(5e-5, 3e-4)] came form a different run of the model and lr_finder
# Hence they dont match the lr_finder plot above
learn.fit_one_cycle(2, max_lr=slice(5e-5, 3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.290142</td>
#       <td>0.171264</td>
#       <td>0.064000</td>
#       <td>0.936000</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.238992</td>
#       <td>0.133074</td>
#       <td>0.048000</td>
#       <td>0.952000</td>
#       <td>01:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
# learn.load('stage-1');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
# doc(interp.plot_top_losses)
# Prediction / Actual / Loss / Probability
interp.plot_top_losses(9, figsize=(15,11))
# Looks like the dataset will need some cleaning. Many images are actually mislabelled

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# **<font color = red>Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.</font>**

# %% [markdown]
# In order to clean the entire set of images, we need to create a new dataset without the split. The video lecture demostrated the use of the `ds_type` param which no longer has any effect. See [the thread](https://forums.fast.ai/t/duplicate-widget/30975/10) for more details.

# %%
# db = (ImageList.from_folder(path)
#                    .split_none()
#                    .label_from_folder()
#                    .transform(get_transforms(), size=224)
#                    .databunch()
#      )

# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
                   .no_split()
                   .label_from_df()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet50, metrics=[error_rate, accuracy])
learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)  # Top Losses on the entire dataset (not just validation)

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
# Don't run this in google colab or any other instances running jupyter lab.
# If you do run this on Jupyter Lab, you need to restart your runtime and
# runtime state including all local variables will be lost.
ImageCleaner(ds, idxs, path)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# If the code above does not show any GUI(contains images and buttons) rendered by widgets but only text output, that may caused by the configuration problem of ipywidgets. Try the solution in this [link](https://github.com/fastai/fastai/issues/1539#issuecomment-505999861) to solve it.

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %% [markdown]
# Make sure to recreate the databunch and `learn_cln` from the `cleaned.csv` file. Otherwise the file would be overwritten from scratch, losing all the results from cleaning the data from toplosses.

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20' class='' max='20', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20/20 01:02<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'burj'/'00000000.jpg')
img
# Out:
# Image (3, 500, 285)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, just make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class, pred_idx, outputs = learn.predict(img)
pred_class
# Out:
# Category burj

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %%
defaults.device = torch.device('cuda')  # Reseting to use GPU

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(2, max_lr=0.5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>87.714691</td>
#       <td>111110.234375</td>
#       <td>0.892000</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>76.554535</td>
#       <td>503.086700</td>
#       <td>0.700000</td>
#       <td>00:59</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %% [markdown]
# <font color=red>**Large learning rate causes the `validation loss` to blow up.**</font>

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result (**these are from fastai's example, not from my example**):
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.755759</td>
#       <td>2.428009</td>
#       <td>0.928000</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.667083</td>
#       <td>2.318772</td>
#       <td>0.904000</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.617163</td>
#       <td>2.233519</td>
#       <td>0.880000</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.561381</td>
#       <td>2.207891</td>
#       <td>0.884000</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.498656</td>
#       <td>2.187772</td>
#       <td>0.860000</td>
#       <td>00:56</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %% [markdown]
# * <font color = red>**The progress is very slow. As well as taking a really long time, it's getting too many looks at each image, so may overfit.**</font>
# * <font color = red>**Also, another symtom of low learning rate is that train error will be higher than the validation error.**</font>
#
# ### SOLUTION:
# * <font color = green>**Train it some more (for more epochs).**</font>
# * <font color = green>**Or train with a higher learning rate.**</font>

# %% [markdown]
# ### Too few epochs

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.255817</td>
#       <td>1.902798</td>
#       <td>0.724000</td>
#       <td>00:58</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * <font color = red>**Training loss is higher than validation loss. (Looks very much similar to low learning rate problem.**</font>
#
# ### SOLUTION:
# * <font color = green>**Train it some more (for more epochs).**</font>

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
# According to Jeremy Howard, it is very hard to overfit these models.
# Turned off everything that prevents overfitting --> to show that model can overfit if num epochs is large
data = ImageDataBunch.from_folder(path,
                                  train=".",
                                  valid_pct=0.9,
                                  bs=16,
                                  ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0),
                                  size=224,
                                  num_workers=4
                                 ).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.444383</td>
#       <td>2.293841</td>
#       <td>0.887916</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.342567</td>
#       <td>2.223855</td>
#       <td>0.851138</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.275875</td>
#       <td>2.163151</td>
#       <td>0.829247</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.163201</td>
#       <td>2.041586</td>
#       <td>0.758319</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.043077</td>
#       <td>1.840277</td>
#       <td>0.644483</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# * <font color = red>**Validatiion error rate reduces for a while then it starts to increase again. Causes overfitting the model.**</font>
#
# ### SOLUTION:
# * <font color = green>**Train it for less number of epochs.**</font>
